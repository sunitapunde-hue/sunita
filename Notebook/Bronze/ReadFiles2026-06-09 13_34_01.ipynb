# %%
dataframe =spark.read.format("csv").option("header","true").option("inferSchema","true").load("/Volumes/sunita_project/default/volumes/upload_4415cdc7-f23b-4ba8-9845-2f9263aab9d0.csv")
dataframe.createOrReplaceTempView("StudentData")
display(dataframe)
